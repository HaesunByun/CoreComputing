# %% [markdown]
# ---
# <font color='Blue' size="4">
# L0444.000500 컴퓨팅 핵심: 컴퓨터로 생각하기(Core Computing: Thinking with Computers)</font>
#
# ---

# %% [markdown]
# # 실습 WEEK13: 가중치그래프

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습은 도전 실습 전에 워밍업으로 풀어보는 문제입니다.
# - **<font color='blue'>도전 실습 문제는 etl>우리강좌>코딩수업>에 접속한 후, 해당 주차 문제의 소스코드를 제출하여 테스트를 통과해야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 코딩수업(엘리스코딩)의 해당 주차 응시 기간을 확인해주세요.</font>**
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# # [도전 실습 문제]

# %% [markdown]
# ### Problem: (함께)도시 연결 최소 비용 네트워크(크루스칼 알고리즘으로 해결하기)
#
# 😄 5개의 도시가 있습니다. 이 도시들은 서로 연결하는 도로를 건설하려고 합니다. 각 도로를 건설하는 비용이 주어질 때, 모든 도시를 연결하는 최소 비용 네트워크를 구축하세요.
#
# ---
# 입력으로는 다음과 같은 형식으로 도로 정보가 주어집니다:
# - 각 줄은 세 개의 정수 u, v, w로 이루어져 있으며, 이는 도시 u와 도시 v를 연결하는 도로의 비용이 w라는 의미
# - 도시는 1번부터 5번까지 번호가 매겨져 있음
# - 여기에서는 매번 입력받기 귀찮으므로 코드로 아예 주어진다.
#
# 출력으로는 모든 도시를 연결하는 최소 비용과, 선택된 도로들의 목록을 출력하세요.
#
# <font color='blue'>`Test Case-1`</font>
#
# Output Sample
# ```
# 최소 비용: 14
# 선택된 도로: [(2, 3), (2, 4), (1, 2), (3, 5)]
# ```

# %% [markdown]
# <크루스칼 알고리즘으로 최소비용 신장트리를 만드는 방법>
#
#   1. 그래프의 모든 간선을 가중치에 따라 오름차순으로 정렬한다.
#   2. 가장 가중치가 작은 간선 e를 뽑는다.
#   3. e를 넣어 신장트리에 사이클이 생기면 넣지 않고, 2번으로 이동한다.
#   4. 사이클이 생기지 않으면 최소 신장 트리에 삽입한다.
#   5. n-1개의 간선이 삽입될 때 까지 2번으로 이동한다.

# %%
def kruskal(nodes, edges):


    return mst_cost, mst

# 입력 데이터
nodes = [1, 2, 3, 4, 5]
edges = [
    (1, 2, 3),
    (1, 3, 4),
    (2, 3, 1),
    (2, 4, 2),
    (3, 4, 5),
    (3, 5, 6),
    (4, 5, 7),
]

# 크루스칼 알고리즘 실행
mst_cost, mst_edges = kruskal(nodes, edges)

# 결과 출력
print(f"최소 비용: {mst_cost}")
print("선택된 도로:", mst_edges)

# %% [markdown]
# ## Problem: (함께) 작은 섬 연결하기 <프림알고리즘으로 해결하기>
# 😄 4개의 섬이 있고, 이 섬들을 다리로 연결하려고 합니다. 다리를 건설하는 비용이 주어질 때, 모든 섬을 연결하는 최소 비용을 계산하세요.
#
# 입력으로는 노드와 엣지 정보가 코드로 주어져 있습니다.
# 엣지정보의 각 줄은 세 개의 정수 u, v, w로 이루어져 있으며, 이는 섬 u와 섬 v를 연결하는 다리의 비용이 w라는 의미입니다. 섬은 1번부터 4번까지 번호가 매겨져 있습니다.

# %% [markdown]
# <font color='blue'>`Test Case-1`</font>
#
#
# Output Sample
# ```
# 최소 비용: 11
# 선택된 다리: [(1, 3, 3), (3, 2, 2), (2, 4, 6)]
# ```

# %%
import heapq

def prim_algorithm(nodes, edges):



    return min_cost, mst_edges

# 입력 데이터
nodes = [1, 2, 3, 4]
edges = [
    (1, 2, 4),
    (1, 3, 3),
    (2, 3, 2),
    (2, 4, 6),
    (3, 4, 5),
]

# 프림 알고리즘 실행
min_cost, mst_edges = prim_algorithm(nodes, edges)

# 결과 출력
print(f"최소 비용: {min_cost}")
print("선택된 다리:", mst_edges)

# %% [markdown]
# ## Problem: (함께)최단 경로 계산하기 <다익스트라 알고리즘으로 해결하기>
#
# 😄당신은 도시 1에서 출발해 다른 도시로 가려 합니다. 도시들은 서로 도로로 연결되어 있고, 각 도로에는 이동 시간이 적혀 있습니다. 도시 1에서 출발했을 때 각 도시로 가는 최단 이동 시간을 구하세요.
#
# 다음은 도시 간 도로와 이동 시간입니다:
# ```
# 도시 1 ↔ 도시 2: 4
# 도시 1 ↔ 도시 3: 2
# 도시 2 ↔ 도시 3: 5
# 도시 2 ↔ 도시 4: 10
# 도시 3 ↔ 도시 4: 3
# 도시 4 ↔ 도시 5: 1
# 도시 3 ↔ 도시 5: 8
# ```
# <font color='blue'>`Test Case-1`</font>
#
#
# Output Sample
# ```
# 도시 1에서 각 도시로 가는 최단 이동 시간: {1: 0, 2: 4, 3: 2, 4: 5, 5: 6}
# ```

# %%
import heapq

# 그래프 데이터 정의
graph = {
    1: [(2, 4), (3, 2)],
    2: [(3, 5), (4, 10)],
    3: [(4, 3), (5, 8)],
    4: [(5, 1)],
    5: []
}

# 다익스트라 알고리즘 구현
def dijkstra(graph, start):




    return distances

# 실행
start_node = 1
shortest_distances = dijkstra(graph, start_node)
print(f"도시 {start_node}에서 각 도시로 가는 최단 이동 시간: {shortest_distances}")

# %% [markdown]
# # [완전 실습 문제]

# %% [markdown]
# ## Problem: K번째 최단 경로 찾기 <다익스트라 알고리즘으로 해결하기>
# 😄 A는 여러 도시를 돌며 여행을 다닐 계획이다. 그런데 A는 ‘느림의 미학’을 중요시하는 사람이라 항상 최단 경로로만 이동하는 것은 별로 좋아하지 않는다. 하지만 너무 시간이 오래 걸리는 경로도 그리 매력적인 것만은 아니어서 적당한 타협안인 ‘K번째 최단 경로’를
# 구하길 원한다. 그를 돕기 위해 K번째 최단 경로를 찾는 프로그램을 작성해보자.
#
# 입력으로는
# - 첫번째 줄에 n, m, k 입력 ( 1 ≤ n ≤ 1000, 1 ≤ m ≤ 2000000, 1 ≤ k ≤ 100)
# - n과 m은 각각 A가 여행을 고려하고 있는 도시들의 개수와 도시 간에 존재하는 도로의 수
# - 이어지는 m개의 줄에는 각각 도로의 정보를 제공하는 3개의 정수 a, b, c가 포함됨
#   - a번 도시에서 b번 도시로 갈 때는 c의 시간이 걸린다는 의미 (1 ≤ a, b ≤ n. 1 ≤ c ≤ 1000)
# - 도시 번호는 1번부터 n번까지 연속해 있고 1번은 시작도시
#
# 출력으로는
# - n개의 줄 출력. i번째 줄에 1번 도시에서 i번 도시로 가는 K번째 최단 경로의 소요 시간 출력
# - 경로의 소요 시간은 경로 위에 있는 도로들을 따라 이동하는 데 필요한 시간들의 합
# - K번째 최단 경로가 존재하지 않으면 -1출력하며 최단 경로에 같은 노드 여러 번 포함 가능

# %% [markdown]
# <font color='blue'>`Test Case-1`</font>
#
# Input Sample
# ```
# 5 10 2
# 1 2 2
# 1 3 7
# 1 4 5
# 1 5 6
# 2 4 2
# 2 3 4
# 3 4 6
# 3 5 8
# 5 2 4
# 5 4 1
# ```
# Output Sample
# ```
# -1
# 10
# 7
# 5
# 14
# ```

# %% [markdown]
# <문제 분석>
# 1. 시작점과 도착점이 주어지고 이 목적지까지 가는 K번째 최단 경로를 구하는 문제
# 2. 도시(노드)의 개수는 1,000개, 도로(에지)의 수는 2,000,000이면서 시간 제약이 2초이므로 다익스트라로 접근
# 3. 문제에서 가장 고민되는 부분은 최단 경로가 아니라 K번째 최단 경로
#   - K번째 최단 경로 해결 방법
#     - 최단 경로를 표현하는 리스트를 K개의 row를 갖는 2차원 리스트의 형태로 변경하고자 한다. 이렇게 하면 최단 경로뿐 아니라 최단경로 ~K번째 최단 경로까지 표현할 수 있다.
#     - 기존 다익스트로 로직에서 사용한 노드를 방문 리스트에 체크해 두고 다음 도착 시 해당 노드를 다시 사용하지 않도록 설정하는 부분은 삭제가 필요해 보인다. K번째 경로를 찾기 위해서는 노드를 여러 번 쓰는 경우가 생기기 때문이다.

# %% [markdown]
# 1. 주어진 예제 데이터를 기반으로 그래프를 그림. 도시는 노드로, 도로는 엣지로 표현
# <div align="center"><img src="https://haesunbyun.github.io/common/images/graph100.PNG">
#
# 2. 변수를 선언하고, 그래프 데이터를 받는 부분은 다익스트라 알고리즘 준비 과정과 동일
# <div align="center"><img src="https://haesunbyun.github.io/common/images/graph101.PNG">

# %% [markdown]
# 3. 유일하게 다른 점은 최단 거리 리스트를 1차원이 아닌 K개의 row를 갖는 2차원 리스트로 선언, 최단 거리 리스트는 최초 시작 노드의 첫 번째 경로는 0, 그 외의 경로는 무한 대로 초기화
# - 최단 거리 리스트 채우기 규칙
#
#   (1) 우선순위 큐에서 연결된 노드와 가중치 데이터를 가져온다.
#
#   (2) 연결 노드의 K번째 경로와 신규 경로를 비교해 신규 경로가 더 작을 때 업데이트한다. 이때 경로가 업데이트되는 경우 거리 배열을 오름차순으로 정렬하고 우선순위 큐에 연결 노드를 추가한다.
#
#   (3) 1~2단계를 우선순위 큐가 비워질 때까지 반복한다. K번째 경로를 찾기 위해 노드를 여러 번 방문하는 경우가 있으므로 기존 다익스트라의 방문 노드를 체크하여 재사용하지 않는 로직은 구현하지 않는다.
#
#   <div align="center"><img src="https://haesunbyun.github.io/common/images/graph102.PNG">
#
# 4. 최단 거리 배열을 탐색하면서 K번째 경로가 존재하면 출력하고, 존재하지 않으면 -1 출력
#   <div align="center"><img src="https://haesunbyun.github.io/common/images/graph103.PNG">

# %% [markdown]
# ## Problem: 타임머신으로 빨리 가기<벨만-포드 알고리즘으로 해결하기>
#
# - N개의 도시와 한 도시에서 출발해 다른 도시에 도착하는 버스가 M개 있다. 각 버스는 A,
# B, C로 나타낼 수 있는데, A는 시작 도시, B는 도착 도시, C는 버스를 타고 이동하는 데
# 걸리는 시간이다.
# - 시간 C가 양수가 아닐 때가 있다.
# - C = 0일 경우에는 순간 이동을 할 때, C < 0일 경우에는 타임머신으로 시간을 되돌아 갈때다. 1번 도시에서 출발해 나머지 도시로 가는 가장 빠른 시간을 구하는 프로그램을 작성
# 해보자.
#
# 입력으로는
# - 1번째 줄에서 도시의 개수 N (1 ≤ N ≤ 500), 버스 노선의 개수 M (1 ≤ M ≤ 6,000)이 주어진다.
# - 2번째 줄부터 M개의 줄에는
# 버스 노선의 정보 A, B, C (1 ≤ A, B ≤ N,-10,000 ≤ C ≤ 10,000)가 주어진다.
#
# 출력으로는
# - 1번 도시에서 출발해 어떤 도시로 가는 과정에서 시간을 무한히 오래 전으로 되돌릴 수 있다면 1번째 줄에 -1을 출력한다. (음의 사이클이 있다고 판단하면 모든 노드에 대해 최단 경로를 계산하는 것이 불가능하므로 -1을 출력)
# - 그렇지 않다면 N-1개 줄에 걸쳐 각 줄의 1번 도시에서 출발해 2번 도시, 3번 도시,..., N번 도시로 가
# 는 가장 빠른 시간을 순서대로 출력한다.
# - 만약 이 도시로 가는 경로가 없다면 -1을 출력한다.

# %% [markdown]
# <font color='blue'>`Test Case-1`</font>
#
# Input Sample
# ```
# 5 6
# 1 2 2
# 1 3 4
# 2 3 -1
# 2 4 4
# 3 5 3
# 4 5 -2
# ```
# Output Sample
# ```
# 노드와 간선의 수:
# 시작 노드, 끝 노드, 간선 가중치 순서로 6개의 간선 입력:
# 1번 노드에서 2번 노드까지의 최단거리는 2
# 1번 노드에서 3번 노드까지의 최단거리는 1
# 1번 노드에서 4번 노드까지의 최단거리는 6
# 1번 노드에서 5번 노드까지의 최단거리는 4
# ```

# %% [markdown]
# 문제 분석하기
# - 시작점 및 다른 노드와 관련된 최단 거리를 구하는 문제
# - 에지에 해당하는 시간이 양수가 아닌 0 또는 음수가 가능
# - 벨만-포드 알고리즘을 사용하여 해결
# <div align="center"><img src="https://haesunbyun.github.io/common/images/graph110.PNG">

# %% [markdown]
# <문제 수행 과정>
# 1. 에지 리스트에 에지 데이터를 저장한 후 거리 리스트를 초기화한다.
# 2. 최초 시작점에 해당하는 거리 리스트 값은 0으로 초기화한다.
# 3. 모든 에지와 관련된 정보를 가져온 후 다음 조건에 따라 거리 리스트의 값을 업데이트한다.
# • 출발 노드가 방문한 적 없는 노드 일 때 값을 업데이트하지 않는다.
# • 출발 노드의 거리 리스트 값 + 에지 가중치 < 종료 노드의 거리 리스트 값일 때 종료 노드의 거리 리스트 값을 업
# 데이트 한다.
#
# 4. 노드 개수 -1 번만큼 3번을 반복한다.
# 5. 음수 사이클 유무를 알기 위해 모든 에지에 관해 다시 한번 3번을 수행한다. 이 때 한 번이라도 값이
# 업데이트되면 음수 사이클이 존재한다고 판단한다.
# 6. 음수 사이클이 존재하면 -1, 존재하지 않으면 거리 리스트의 값을 출력한다. 단, 거리 리스트의 값이
# INF일 경우에는 -1을 출력한다.

# %% [markdown]
# ## Problem: 밸만포드 알고리즘 코드로 이해해보기

# %%
class Graph:
    def __init__(self, vertices):
        self.V = vertices
        self.edges = []
        self.nodes = set()

    def add_edge(self, u, v, w):
        self.edges.append((u, v, w))
        self.nodes.update([u, v])

    def bellman_ford(self, start):
        # 거리 초기화
        distances = {node: float('inf') for node in self.nodes}
        distances[start] = 0

        # 간선 완화
        for i in range(len(self.nodes) - 1):
            print(f"Iteration {i+1}:")
            for u, v, w in self.edges:
                if distances[u] != float('inf') and distances[u] + w < distances[v]:
                    distances[v] = distances[u] + w
                    print(f"Updated distance of {v} to {distances[v]} using edge {u} -> {v} with weight {w}")
            print(f"Distances after iteration {i+1}: {distances}")
            print()

        # 음수 사이클 검출:
        # 음수 사이클이 존재하는 경우,
        # 해당 사이클을 반복해서 순환하면 무한히 작은 경로 비용을 만드는 오류가 발생
        for u, v, w in self.edges:
            if distances[u] != float('inf') and distances[u] + w < distances[v]:
                print("Graph contains a negative-weight cycle")
                return None

        return distances

# 예제 사용
g = Graph(5)
g.add_edge('s', 't', 6)
g.add_edge('s', 'y', 7)
g.add_edge('t', 'y', 8)
g.add_edge('t', 'x', 5)
g.add_edge('t', 'z', -4)
g.add_edge('y', 'x', -3)
g.add_edge('y', 'z', 9)
g.add_edge('x', 't', -2)
g.add_edge('z', 's', 2)
g.add_edge('z', 'x', 7)

start = 's'
distances = g.bellman_ford(start)

if distances:
    print("최단 거리:")
    for node in distances:
        print(f"정점 {start}에서 정점 {node}까지의 거리: {distances[node]}")

# %% [markdown]
# ## Problem: 플로이드-와샬 알고리즘 코드로 이해해보기

# %%
# 무한대 값 정의
INF = float('inf')

def print_matrix(matrix):
    for row in matrix:
        print(["INF" if x == INF else x for x in row])
    print()

def floyd_warshall(graph):
    # 노드 수
    V = len(graph)

    # 거리 행렬 초기화
    dist = list(map(lambda i: list(map(lambda j: j, i)), graph))

    # 초기 행렬 출력
    print("Initial matrix:")
    print_matrix(dist)

    # Floyd-Warshall 알고리즘
    for k in range(V):
        print(f"Using node {k} as an intermediate node:")
        for i in range(V):
            for j in range(V):
                if dist[i][j] > dist[i][k] + dist[k][j]:
                    dist[i][j] = dist[i][k] + dist[k][j]
        print_matrix(dist)

    return dist

# 그래프 정의 (인접 행렬)
graph = [
    [0, 3, 8, INF, -4],
    [INF, 0, INF, 1, 7],
    [INF, 4, 0, INF, INF],
    [2, INF, -5, 0, INF],
    [INF, INF, INF, 6, 0]
]

# 결과 출력
distances = floyd_warshall(graph)

if distances:
    print("최종 최단 거리 행렬:")
    print_matrix(distances)

# %% [markdown]
# ---
# <font color='Blue' size="4">
# L0444.000500 컴퓨팅 핵심: 컴퓨터로 생각하기(Core Computing: Thinking with Computers)</font>
#
# ---
# Prof. Haesun Byun

# %% [markdown]
# # 실습 WEEK10: 정렬 알고리즘

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 도움이 됩니다.
# - **<font color='blue'>도전 실습 문제는 etl>우리강좌>코딩수업>에 접속한 후, 해당 주차 문제의 소스코드를 제출하여 테스트를 통과해야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 코딩수업(엘리스코딩)의 해당 주차 응시 기간을 확인해주세요.</font>**
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도 풀이를 하지 않습니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# ### 데이터 입력과 출력 예
# 😄문자열을 입력받아 출력하시오.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 즐거워
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: 즐거워
# ```
#
#
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# Say! I can do it!
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: Say! I can do it!
# ```

# %%
input_data = input('문자열: ')
print(f'출력결과: {input_data}')
# Out:
# 문자열: Say! I can do it!
# 출력결과: Say! I can do it!

# %% [markdown]
# ## [사전 실습 문제]

# %% [markdown]
# ### Problem: 중앙값 구하기◼◻◻◻◻

# %% [markdown]
# 😄 중앙값은 주어진 수를 크기 순서대로 늘어 놓았을 때 가장 중앙에 놓인 값이다. 예를 들어 10, 40, 30, 60, 30의 경우, 크기 순서대로 늘어 놓으면 10 30 30 40 60이 되고 따라서 중앙값은 30이 된다.
# 값이 짝수개일 때에는 중앙값이 유일하지 않고 두 개가 될 수도 있다. 이 경우 그 두 값의 평균을 취한다. 예를 들어, 10, 20, 90, 200 네 수의 중앙값은 20과 90의 평균인 55가 된다.
#
# 자연수가 주어질 때 이들의 중앙값을 구하는 프로그램을 작성하시오. 파이썬의 sort()나 sorted()를 사용하지 않고 구현하시오.
# 주어지는 자연수는 1000 보다 작은 10의 배수이다.
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 10 40 30 60 30
# ```
# Output Sample
# ```
# 30
# ```
#
# <font color='blue'>`test case-2`</font>
# Input Sample
# ```
# 10 20 90 200
# ```
# Output Sample
# ```
# 55
# ```

# %% [markdown]
# ### Problem: 상을 받는 커트라인 점수 ◼◻◻◻◻

# %% [markdown]
# 😄 서울대학교 기초교육원에서는 컴퓨팅프로젝트 경진대회를 실시한다.
# <div align="center"><a href='https://liberaledu.snu.ac.kr/node/241'><img src="https://haesunbyun.github.io/common/images/LIB_T_2.png" height=300 style="width:600px;"></a> </div>
#
#
# 이번 $N$개의 팀이 참여했다. 이들 중 점수가 가장 높은 $k$개의 팀은 상을 받을 것이다. 이 때, 상을 받는 커트라인이 몇 점인지 구하시오. 파이썬의 sort()나 sorted()를 사용하지 않고 구현하시오.
#
# 커트라인이란 상을 받는 사람들 중 점수가 가장 가장 낮은 사람의 점수를 말한다.
#
# 첫째 줄에는 출전 팀의 수 $N$과 상을 받는 팀의 수 $k$가 공백을 사이에 두고 주어진다.
#
# 둘째 줄에는 각 팀의 점수 $x$가 공백을 사이에 두고 주어진다.
# 상을 받는 커트라인을 출력하라.
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 5 2
# 100 76 85 93 98
# ```
# Output Sample
# ```
# 98
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 7 3
# 97 76 60 83 92 98 88
# ```
# Output Sample
# ```
# 92
# ```

# %% [markdown]
# ## [도전 실습 문제]

# %% [markdown]
# ### Problem: (함께) 간담회에서 악수하기◼◼◻◻◻
#
# 😄 조교&튜터 간담회가 열렸다. 참석한 사람에게는 각각 m부터 n까지의 번호가 하나씩 부여된다. 즉, 간담회에 참석한 총 인원은 n-m+1명이다.
# 악수 시간이 되어, 사람들이 특별한 조건에 따라 악수를 한다. 두 사람은 그 사람의 번호를 더했을 때 5의 배수이거나 7의 배수일 때만 한 번 악수를 한다. 그렇지 않을 경우 그 두 사람은 악수를 하지 않는다. 가령 m=3, n=7일 경우 5명에게 3, 4, 5, 6, 7의 번호가 부여된다. 이 경우 3번과 7번, 4번과 6번, 3번과 4번이 한번씩 악수를 하며, 나머지는 악수를 하지 않는다. 이 때 간담회내의 총 악수 횟수를 구하시오.
#
# 입력은 한 줄로 이루어져 있고 첫째 줄에 자연수 m, n이 공백으로 구분되어 들어온다. (1 ≤ m ≤ n ≤ 1 000)
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 3 7
# ```
# Output Sample
# ```
# 3
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 4 4
# ```
# Output Sample
# ```
# 0
# ```

# %% [markdown]
# ### Problem: (스스로)문서정렬하기(버블정렬) ◼◼◼◻◻
#
# 😄 어느 회사의 문서 이름 형식은 다음과 같다. 가장 먼저 문서가 작성된 달(month)이 숫자로 적혀있다. 그 다음은 문서의 제목이 공백 없이 적힌다. 그리고 공백없이 바로 이어서 동일한 제목이 역순으로 적힌다. 즉 문서 이름의 구성은 (월)(문서제목)(역순문서제목)과 같다. 예를 들어, 5월에 작성된 제목이 'employees'인 문서 이름 '5employeesseeyolpme'이다.
#
# 이러한 문서들을 '제목' 순으로 정렬하여 출력하려고 한다. 이때  역순으로 적힌 뒷 부분은 고려하지 않고 문서 제목 자체만 기준으로 정렬한다. 정렬해야 될 문서의 '제목'은 길이가 모두 같다. 또한 문서 제목이 같은 경우, 입력 받은 순서를 유지한다. 문서의 제목은 영어로만 이루어져 있다.
#
# 첫째 줄에는 N(정렬해야될 문서 개수)이 주어진다. 다음 줄 부터 길이 n(문서 이름의 길이)의 문자열이 한 줄에 한 개씩 N개 이상 주어진다. (n >= 2 , N >= 1)
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 6
# 5employeesseeyolpme
# 12foodlistsstsildoof
# 1workaloneenolakrow
# 10ihateworkkrowetahi
# 9workagainniagakrow
# 1payinmoreeromniyap
# ```
#
# Output Sample
# ```
# 5employeesseeyolpme
# 12foodlistsstsildoof
# 10ihateworkkrowetahi
# 1payinmoreeromniyap
# 9workagainniagakrow
# 1workaloneenolakrow
# ```
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 4
# 12christmassamtsirhc
# 10leafshadoodahsfael
# 9mybirthdaadhtribym
# 8happyhoilliohyppah
# ```
# Output Sample
# ```
# 12christmassamtsirhc
# 8happyhoilliohyppah
# 10leafshadoodahsfael
# 9mybirthdaadhtribym
# ```

# %% [markdown]
# ### Problem: (스스로) 선착순 경품 이벤트(삽입정렬)◼◼◼◻◻
#
# 😄 경품 이벤트가 진행되고 있다. 이번 경품 이벤트는 전화번호 뒷 4자리 숫자가 낮은 N명에게 경품을 주려고 한다. 진행자는 고심 끝에 사람들을 줄 세울 방법을 생각해냈다.
# 두 번째 사람이 자기보다 낮은 숫자를 가진 사람이 등장할 때까지 비교하다가 낮은 숫자를 가진 사람이 등장하면 그 사람과 자리를 바꾼다. 첫번째 자리로 오면 비교를 중지한다. 샘플을 보면 상은(1256)이 영훈(5433)보다 낮은 숫자여서 자리를 바꾼다. 세 번째 사람은 앞의 사람들과 비교하여 자기 자리를 찾아 들어간다. 샘플의 경우 예은(3534)이 영훈(5433)보다 작고 상은(1256)보다 크므로 1256, 3534, 5433 이렇게 들어간다.
#     …
# 이와 같이 두번째 사람부터 M번째 사람까지 앞 자리 중 자기보다 낮은 숫자를 가진 사람이 나올 때까지 비교하다가 자리를 바꾸는 과정을 M-1번 진행한다.
#
# 매번 자리를 바꿀 때마다 알맞게 자리를 바꿨는지 확인하기 위해 중간과정을 보려고 이를 리스트로 출력한다. 그 후, 마지막 경품 수령자의 이름을 출력한다.
#
# 입력은 두 줄이다. 첫째줄은 dictionary 형태(숫자 4자리: "이름")의 문자열, 둘째줄은 경품을 받을 사람 수 N(1이상)이 주어진다. 같은 전화번호를 지닌 사람은 없다. 줄세워지는 과정을 출력하고 누구까지 경품을 받을 수 있는지 출력하시오.
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# {5433:"영훈",1256:"상은",3534:"예은",8989:"한솔",2407:"영미",7777:"준범",6353:"현석"}
# 6
# ```
# Output Sample
# ```
# [1256, 5433, 3534, 8989, 2407, 7777, 6353]
# [1256, 3534, 5433, 8989, 2407, 7777, 6353]
# [1256, 3534, 5433, 8989, 2407, 7777, 6353]
# [1256, 2407, 3534, 5433, 8989, 7777, 6353]
# [1256, 2407, 3534, 5433, 7777, 8989, 6353]
# [1256, 2407, 3534, 5433, 6353, 7777, 8989]
# 준범
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# {5433:"영훈",1256:"상은",3534:"예은",8989:"한솔",2407:"영미",7777:"준범",6353:"현석"}
# 4
# ```
#
# Output Sample
# ```
# [1256, 5433, 3534, 8989, 2407, 7777, 6353]
# [1256, 3534, 5433, 8989, 2407, 7777, 6353]
# [1256, 3534, 5433, 8989, 2407, 7777, 6353]
# [1256, 2407, 3534, 5433, 8989, 7777, 6353]
# [1256, 2407, 3534, 5433, 7777, 8989, 6353]
# [1256, 2407, 3534, 5433, 6353, 7777, 8989]
# 영훈
# ```

# %% [markdown]
# ## [완전 실습 문제]

# %% [markdown]
# ### Problem: 하이브리드◼◼◼◻◻

# %% [markdown]
# 😄 설윤이는 다음과 같은 하이브리드 정렬 체계를 고안하였다.
#
# (1) 주어진 수열에 대하여, 버블 정렬을 한 Round 수행함으로써 수열의 마지막 항을 확정짓는다.
#
# (2) 값이 확정된 마지막 항을 제외한 부분수열에 대하여, 선택 정렬을 한 Round 수행함으로써 수열의 첫 번째 항을 확정짓는다.
#
# (3) 정렬이 완료될 때까지 위와 같이 버블 정렬과 선택 정렬을 번갈아 반복한다.
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/sortPrac.png" height=300 style="width:600px;"></div>
#
#
# 이를테면 위와 같이 [9, 4, 8, 1, 2] 수열을 오름차순으로 정렬하는 상황을 생각하자. 첫 번째 Round 결과 수열은 [4, 8, 1, 2, 9]로 변화하며 두 번째 Round 결과 수열은 [1, 8, 4, 2, 9]로 변화한다.
#
# 크기가 N인 수열을 입력받아, 위에서와 같은 하이브리드 정렬을 수행하는 Python 프로그램을 작성하시오. 수열의 각 항은 띄어쓰기로 구분되어 입력되며, 매 Round가 끝날 때마다 중간 결과를 출력해야 한다. 수열을 오름차순으로 정렬할지 내림차순으로 정렬할지도 사용자로부터 입력받는다고 가정한다.
#
# ---
# Input Sample
# ```
# 9 4 8 1 2
# 오름차순
# ```
# Output Sample
# ```
# 4 8 1 2 9
# 1 8 4 2 9
# 1 4 2 8 9
# 1 2 4 8 9
# ```
#
# ---
# Input Sample
# ```
# 50 10 30 80
# 내림차순
# ```
# Output Sample
# ```
# 50 30 80 10
# 80 30 50 10
# 80 50 30 10
# ```

# %% [markdown]
# ### Problem: 2차원 좌표 정렬하기

# %% [markdown]
# 😄 2차원 평면 위의 점 N개가 주어진다. 좌표를 x좌표가 증가하는 순으로, x좌표가 같으면 y좌표가 증가하는 순서로 정렬한 다음 출력하는 프로그램을 작성하시오.
#
# 첫째 줄에 점의 개수 N이 주어진다. 둘째 줄부터 N개의 줄에는 i번 점의 위치 xi와 yi가 주어진다. 좌표는 항상 정수이고, 위치가 같은 두 점은 없다.
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 5
# 3 4
# 1 1
# 1 -1
# 2 2
# 3 3
# ```
# Output Sample
# ```
# 1 -1
# 1 1
# 2 2
# 3 3
# 3 4
# ```

# %% [markdown]
# ### Problem: 버블 정렬(Bubble Sort) 그래픽으로 구현하기
#
# 😄 2차원 평면 위의 점 10개(10행 2열의 배열)를 랜덤으로 만들고 x좌표와 y좌표의 값을 오름차순 버블정렬로 정렬하는 모습을 산포도 그래프로 시각화해보시오.
#
# <font color='blue'> Test Case-1</font>
#
# Output Sample
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/sort17.png" height=300 style="width:600px;"></div>

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output


def bubble_sort_2d_array(arr):
    #Todo







        # 정렬 과정 시각화를 위해 산포도 그래프 출력
        clear_output(wait=True)
        plt.scatter(range(total_elements), flattened_arr, s=10)
        plt.pause(0.1)

    return sorted_arr

# 2차원 배열 생성
random_array = np.random.randint(1,100,(10,2))

# 초기 배열의 산포도 그래프 출력
plt.scatter(random_array[:,0], random_array[:, 1],s=10)
plt.pause(1)

sorted_array = bubble_sort_2d_array(random_array)

# %% [markdown]
# ---
# <font color='Blue' size="4">
# L0444.000500 컴퓨팅 핵심: 컴퓨터로 생각하기(Core Computing: Thinking with Computers)</font>
#
# ---

# %% [markdown]
# # 실습 WEEK12: 그래프

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습은 도전 실습 전에 워밍업으로 풀어보는 문제입니다.
# - **<font color='blue'>도전 실습 문제는 etl>우리강좌>코딩수업>에 접속한 후, 해당 주차 문제의 소스코드를 제출하여 테스트를 통과해야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 코딩수업(엘리스코딩)의 해당 주차 응시 기간을 확인해주세요.</font>**
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# # [도전 실습 문제]

# %% [markdown]
# ### Problem: (함께)음료수 얼려먹기<DFS로 풀이해보기>
#
# 😄 NxM 크기의 얼음 틀이 있습니다. 구멍이 뚫려 있는 부분은 0, 칸막이가 존재하는 부분은 1로 표시됩니다. 구멍이 뚫려 있는 부분끼리 상, 하, 좌, 우로 붙어 있는 경우 서로 연결되어 있는 것으로 간주합니다. 그리고 구멍이 뚫려 있는 부분에 아이스크림을 만들 수 있습니다.
# 이때 얼음 틀의 모양이 주어졌을 때 생성되는 총 아이스크림의 개수를 구하는 프로그램을 작성하세요. 다음의 4x5 얼음 틀 예시에서는 아이스크림이 총 3개 생성됩니다.
#
# <div><img src="https://haesunbyun.github.io/common/images/matrix1.PNG" width=300></div>
#
# ---
# 입력으로는
# - 첫 번째 줄에 얼음 틀의 세로 길이 N과 가로 길이 M이 주어짐(1 <= N, M <= 1000)
# - 두 번째 줄부터 N + 1번째 줄까지 얼음 틀의 형태가 주어짐
# - 이때 구멍이 뚫려 있는 부분은 0, 그렇지 않은 부분은 1
#
# <font color='blue'>`Test Case-1`</font>
#
# Input Sample
# ```
# 4 5
# 00110
# 00011
# 11111
# 00000
# ```
# Output Sample
# ```
# 얼음틀의 사이즈를 입력하세요:
# 1번째 줄의 얼음 틀 상태를 입력하시오:
# 2번째 줄의 얼음 틀 상태를 입력하시오:
# 3번째 줄의 얼음 틀 상태를 입력하시오:
# 4번째 줄의 얼음 틀 상태를 입력하시오:
# Output: 만들 수 있는 아이스크림은 총 3개입니다.
# ```

# %% [markdown]
# <문제 해결 아이디어>
# - 이 문제는 DFS 혹은 BFS로 해결
# - 얼음을 얼릴 수 있는 공간이 상, 하, 좌, 우로 연결되어 있다고 표현할 수 있으므로 그래프 형태
# 로 모델링 할 수 있음
# - 그림처럼 3x3 크기의 얼음 틀이 있다고 가정
#
# <div><img src="https://haesunbyun.github.io/common/images/matrix2.PNG" width=300></div>
#
# <문제 해결 아이디어> : DFS를 활용하는 알고리즘
# 1. 특정한 지점의 주변 상, 하, 좌, 우를 살펴본 뒤에
# 주변 지점 중에서 값이 ‘0’이면서 아직 방문하지
# 않은 지점이 있다면 해당 지점을 방문
# 2. 방문한 지점에서 다시 상, 하, 좌, 우를 살펴보면서 방문을 진행하는 과정을 반복하면, 연결된 모든 지점을 방문할 수 있음
# 3. 모든 노드에 대하여 1 ~ 2번의 과정을 반복하며, 방문하지 않은 지점의 수를 카운트

# %%
def dfs(x, y):
  pass







# N, M을 공백을 기준으로 구분하여 입력 받기
n, m = map(int, input("얼음틀의 사이즈를 입력하세요: ").split())

# 2차원 리스트의 맵 정보 입력 받기
graph = []
for i in range(n):
    graph.append(list(map(int, input(f"{i+1}번째 줄의 얼음 틀 상태를 입력하시오: "))))

# %% [markdown]
# ## Problem: <스스로> 미로 탈출 <BFS로 풀이해보기>
# 😄 A는 NxM 크기의 직사각형 형태의 미로에 갇혔습니다. 미로에는 여러 마리의 괴물이 있어 이를 피해 탈출해야 합니다.
# - A의 위치는 (1, 1)이며 미로의 출구는 (N, M)의 위치에 존재하며 한 번에 한칸씩 이동할 수 있습니다. 이때 괴물이 있는 부분은 0으로, 괴물이 없는 부분은 1로 표시되어 있습니다. 미로는 반드시 탈출할 수 있는 형태로 제시됩니다.
# - 이때 A가 탈출하기 위해 움직여야 하는 최소 칸의 개수를 구하세요. 칸을 셀때는 시작 칸과 마지막 칸을 모두 포함해서 계산합니다.
#
# ---
# <문제 해결 아이디어> 미로 탈출
#
# BFS는 시작 지점에서 가까운 노드부터 차례대로 그래프의 모든 노드를 탐색
# - 상, 하, 좌, 우로 연결된 모든 노드로의 거리가 1로 동일
# - 따라서 (1, 1) 지점부터 BFS를 수행하여 모든 노드의 최단 거리 값을 기록하면 해결할 수 있음
# ---
#
# - 예) 3 X 3 크기의 미로가 있다고 가정
# <div><img src="https://haesunbyun.github.io/common/images/matrix3.PNG" width=300></div>
#
# - [Step 1] 처음에 (1, 1)의 위치에서 시작
# <div><img src="https://haesunbyun.github.io/common/images/matrix4.PNG" width=300></div>

# %% [markdown]
# - [Step 2] (1, 1) 좌표에서 상, 하, 좌, 우로 탐색을 진행하면 바로 옆 노드인 (1,2) 위치의 노드를 방문하게 되고 새롭게 방문하는 (1, 2) 지점의 값을 2로 바꿈
# <div><img src="https://haesunbyun.github.io/common/images/matrix5.PNG" width=300></div>
#
# - [Step 3] 마찬가지로 BFS를 계속 수행하면 결과적으로 최단 경로의 값들이 1씩 증가하는 형태로 변경
# <div><img src="https://haesunbyun.github.io/common/images/matrix6.PNG" width=300></div>

# %% [markdown]
# <font color='blue'>`Test Case-1`</font>
#
# Input Sample
# ```
# 5 6
# 101010
# 111111
# 000001
# 111111
# 111111
# ```
# Output Sample
# ```
# 맵의 크기를 입력해주세요:
# 1줄의 맵 정보를 입력해주세요:
# 2줄의 맵 정보를 입력해주세요:
# 3줄의 맵 정보를 입력해주세요:
# 4줄의 맵 정보를 입력해주세요:
# 5줄의 맵 정보를 입력해주세요:
# Output: 최소 이동 칸의 개수는 10입니다.
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### BFS의 과정
# - BFS의 과정은 아래와 같습니다.
#   1. 시작하는 칸을 큐에 넣고 방문했다는 표시를 남긴다.
#   2. 큐에서 원소를 꺼내어 그 칸에 상/하/좌/우로 인접한 4개의 칸에 대해 3번 행동을 한다.
#   3. 해당 칸을 이전에 방문했다면 아무 것도 하지 않고, 처음으로 방문했다면 방문했다는 표시를 남기고 해당 칸을 큐에 넣는다.
#   4. 큐의 모든 원소가 빌 때 까지 2를 반복한다.
#
# - 모든 칸이 큐에 1번 씩만 들어감이 보장되므로 시간복잡도는 칸이 N개일 때 O(N)입니다.
#
# ### BFS - 자주 실수하는 요소
#   1. 시작 점에 방문했다는 표시를 남기지 않는다.
#   2. 큐에 넣을 때 방문했다는 표시를 하지 않고, 큐에서 빼낼 때 방문했다는 표시를 남긴다.
#   3. 이웃한 원소가 범위를 벗어났는지에 대한 체크를 잘못했다.
#   4. 가로와 세로를 헷갈렸다.
#
#
# ### DFS와의 차이 및 주의사항
# - BFS와는 다르게 DFS에서는 현재 보는 칸으로부터 추가되는 인접한 칸은 현재 보는 칸 보다 시작점으로부터 1만큼 더 떨어져있다는 성질이 성립되지 않습니다.
# - 그렇기 때문에 시작점으로부터의 거리를 잴 때는 DFS 대신 BFS를 사용해야 합니다.
#
# ![image.png](data:image/png;base64,...)

# %%
from collections import deque
# 큐(Queue) 구현을 위해 deque 라이브러리 사용


def bfs(x, y):
    pass






# N, M을 공백을 기준으로 구분하여 입력 받기
n, m = map(int, input("맵의 크기를 입력해주세요: ").split())


# 2차원 리스트의 맵 정보 입력 받기
graph = []
for i in range(n):
    graph.append(list(map(int, input(f"{i+1}줄의 맵 정보를 입력해주세요: "))))

# %% [markdown]
# ## Problem: (스스로)  친구 찾기 (DFS)
# 😄 A 라는 사람이 B와 친구이고, B 라는 사람이 C와 친구라면 A와 C는 직접적인 친구 사이는 아니지만 서로 B 라는 친구를 통해서 간접적으로 아는 관계라고 할 수 있다.
# SNS에서 친구 추천을 하기 위해 그래프 알고리즘을 활용하여 친구 관계를 알아보자.
#
# - 친구 관계 정보는 아래와 같다.
#
# 1. Summer와 John은 친구 관계 입니다.
# 2. Summer와 Justin은 친구 관계 입니다.
# 3. Summer와 Mike는 친구 관계 입니다.
# 4. Justin과 May는 친구 관계 입니다.
# 5. May와 Kim은 친구 관계 입니다.
# 6. John과 Justin은 친구 관계 입니다.
# 7. Justin과 Mike는 친구 관계 입니다.
# 8. Tom과 Jerry는 친구 관계 입니다.
#
# - 친구 관계를 그래프로 표현하면 아래와 같다.
# <div><img src="https://haesunbyun.github.io/common/images/graph_friends.PNG" width=500></div>

# %% [markdown]
# <font color='blue'>`Test Case-1`</font>
#
# Input Sample
# ```
# Summer
# ```
# Output Sample
# ```
# 알아보고 싶은 친구를 입력하세요:
# ***Summer의 친구 관계***
# John와(과) 친구입니다.
# Justin와(과) 친구입니다.
# Mike와(과) 친구입니다.
# May와(과) 친구입니다.
# Kim와(과) 친구입니다.
# ```

# %%
def dfs(graph, start, visited=None):






# 친구 관계 그래프 정의
relation = {
    'Summer': ['John', 'Justin', 'Mike'],
    'John': ['Summer', 'Justin'],
    'Justin': ['John', 'Summer', 'Mike', 'May'],
    'Mike': ['Summer', 'Justin'],
    'May': ['Justin', 'Kim'],
    'Kim': ['May'],
    'Tom': ['Jerry'],
    'Jerry': ['Tom']
}

# 알아보고 싶은 친구 입력
friend_to_find = input("알아보고 싶은 친구를 입력하세요: ")
print()
print(f"***{friend_to_find}의 친구 관계***")
dfs(relation, friend_to_find)

# %% [markdown]
# # [완전 실습 문제]

# %% [markdown]
# ## Problem: 친구 관계 찾기 (BFS)
#
# - 이번에는 BFS를 활용하여 친구를 찾고, 친밀도를 파악해보자. 직접 친한 경우 친밀도는 1이고,
# 한 명 건너 친구 관계라면 1씩 더해진다.
#
# - 친구 관계 정보는 아래와 같다.
#
# 1. Summer와 John은 친구 관계 입니다.
# 2. Summer와 Justin은 친구 관계 입니다.
# 3. Summer와 Mike는 친구 관계 입니다.
# 4. Justin과 May는 친구 관계 입니다.
# 5. May와 Kim은 친구 관계 입니다.
# 6. John과 Justin은 친구 관계 입니다.
# 7. Justin과 Mike는 친구 관계 입니다.
# 8. Tom과 Jerry는 친구 관계 입니다.
#
# - 친구 관계를 그래프로 표현하면 아래와 같다.
# - 중복된 관계를 고려하지 않기 위해 양방향 그래프를 구성한다.
# - 양방향 그래프로 친구 관계 그래프를 표현하면 중복 계산을 최소화하고 최단 경로를 찾음
# <div><img src="https://haesunbyun.github.io/common/images/graph_friends2.PNG" width=500></div>
#
# ```
# def build_graph(graph_dict):
#     # 양방향 그래프로 변환
#     graph = defaultdict(set)
#     for person, friends in graph_dict.items():
#         for friend in friends:
#             graph[person].add(friend)
#             graph[friend].add(person)
#     return graph
# ```
# ---

# %% [markdown]
# <font color='blue'>`Test Case-1`</font>
#
# Input Sample
# ```
# Summer Jerry
# ```
# Output Sample
# ```
# 알아보고 싶은 친구를 입력하세요:
# Summer를 기준으로 친구 관계 알아보기:
# Mike와 1촌
# John와 1촌
# Justin와 1촌
# May와 2촌
# Kim와 3촌
#
# Jerry를 기준으로 친구 관계 알아보기:
# Tom와 1촌
# ```

# %% [markdown]
# <문제해결 아이디어> 친구 찾기
#
# 1. 큐 (앞으로 처리해야 할 사람 (이름, 친밀도) 튜플을 저장)와 집합(큐에 추가한 사람을 기록)
# 2. 사용자가 입력한 사람을 큐와 집합에 저장
# 3. 큐에 사람이 남아 있다면 큐에서 하나씩 사람을 꺼내고 (이름, 친밀도) 출력
#  단, 사용자가 입력한 사람은 넘어감
# 4. 꺼낸 사람의 친구들 중 아직 큐에 들어간 적이 없는 사람을 골라서 큐와 집합에 추가
# 5. 큐에 처리할 사람이 아직 남아 있다면 3번의 과정 부터 반복

# %% [markdown]
# ## Problem: 특정 거리의 도시 찾기 <BFS로 풀이해보기>
# 1번부터 N번까지의 도시와 M개의 단방향 도로가 존재하고, 모든 도로의 거리는 1인 도시가 있다. 도시 X로부터 출발해 도달할 수 있는 모든 도시 중 최단 거리가 정확히 K인
# 모든 도시들의 번호를 출력해보자. 단, 출발도시 X에서 출발도시 X로 가는 최단거리는 항상 0이다.
#
# - 입력 조건
#   - 첫 번째 줄에 도시 수(N), 도로 수(M), 최단 거리(K), 출발 도시(X)의 번호가 입력
#   - 2 ≤ N ≤ 300,000, 1 ≤ M ≤ 1,000,000, 1 ≤ K ≤ 300,000, 1 ≤ X ≤ N
#   - 두 번째 줄부터 M개의 줄에 걸쳐 2개의 자연수 A, B가 공백으로 입력
#   - A번 도시에서 B번 도시로 이동하는 단방향 도로가 존재한다는 의미
#   - 1 ≤ A, B ≤ N, 단 A와 B는 같을 수 없음
#
# - 출력 조건
#   - X로부터 출발해 도달 가능한 도시 중 최단 거리가 K인 모든 도시의 번호를 오름차순으로 출력
#   -해당하는 도시가 1개도 존재하지 않으면 “없음”을 출력

# %% [markdown]
# <font color='blue'>`Test Case-1`</font>
#
# Input Sample
# ```
# 4 4 2 1
# 1 2
# 1 3
# 2 3
# 2 4
# ```
# Output Sample
# ```
# 도시 수, 도로 수, 최단 거리, 출발 도시 번호를 입력해주세요:
# 도로로 연결된 도시를 입력해주세요:
# 도로로 연결된 도시를 입력해주세요:
# 도로로 연결된 도시를 입력해주세요:
# 도로로 연결된 도시를 입력해주세요:
# 도시1에서 최단거리가 2인 도시는 4이다.
# ```
#
# <font color='blue'>`Test Case-2`</font>
#
# Input Sample
# ```
# 4 3 2 1
# 1 2
# 1 3
# 1 4
# ```
# Output Sample
# ```
# 도시 수, 도로 수, 최단 거리, 출발 도시 번호를 입력해주세요:
# 도로로 연결된 도시를 입력해주세요:
# 도로로 연결된 도시를 입력해주세요:
# 도로로 연결된 도시를 입력해주세요:
# 없음
# ```

# %% [markdown]
# - <문제해결 아이디어>
#  - 모든 도로의 거리가 1이므로 가중치가 없는 인접 리스트로 그래프를 표현
#  - 도시의 개수가 300,000 도로의 최대 크기가 1,000,000이므로 BFS 탐색을 수행하면 시간 복잡도 내에 해결 가능
# <div><img src="https://haesunbyun.github.io/common/images/graph_city2.PNG" width=500></div>
#
#  - BFS 탐색 알고리즘으로 탐색하면서 각 도시로 가는 최단 거리 값을 방문 리스트에 저장
#  - 최초에는 방문 도시가 1이고, 이동하지 않았으므로 방문 리스트에 0을 저장
#  - 이후 방문하는 도시는 이전 도시의 방문 리스트 값 + 1을 방문 리스트에 저장하는 방식으로 이동 거리를 저장
#  <div><img src="https://haesunbyun.github.io/common/images/graph_city3.PNG" width=500></div>
#  - 탐색 종료 후 방문 배열에 값이 K와 같은 도시의 번호를 출력

# %% [markdown]
# ---
# <font color='Blue' size="4">
# L0444.000500 컴퓨팅 핵심: 컴퓨터로 생각하기(Core Computing: Thinking with Computers)</font>
#
# ---
# Prof. Haesun Byun

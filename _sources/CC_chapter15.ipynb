# %% [markdown]
# ---
# <font color='Blue' size="4">
# F37.204 컴퓨팅 핵심: 컴퓨터로 생각하기(Core Computing: Thinking with Computers)</font>
#
# ---

# %% [markdown]
# # 기말평가

# %% [markdown]
# :::{admonition} 기말평가 안내
# :class: info
# - 기말평가는 공지를 통해 안내됩니다. 고생하셨습니다!
#
# :::

# %% [markdown]
# ---
# <font color='Grey' size="4">
# F37.204 컴퓨팅 핵심: 컴퓨터로 생각하기(Core Computing: Thinking with Computers)</font>
#
# ---
# 서울대학교 학부대학<br>
# 교수 변해선

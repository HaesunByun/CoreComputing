# %% [markdown]
# ---
# <font color='Blue' size="4">
# L0444.000500 컴퓨팅 핵심: 컴퓨터로 생각하기(Core Computing: Thinking with Computers)</font>
#
# ---

# %% [markdown]
# # Chapter 7. 파일 입출력과 예외처리

# %% [markdown]
# :::{admonition} 학습목표와 기대효과
# :class: info
# - 학습목표
#   - Main memory vs. File system의  특징을  알아보자.
#   - 파이썬에서  파일을  open, read, write, close하는  방법을  알아보자.
#   - 프로그램 실행 중 발생할 수 있는 오류를 처리하는 예외처리에 대해서 학습해보자.
#
# - 기대효과
#   - 코드를 통해 시스템과 연동시켜 파일을 관리(management) 할 수 있다.
#   - 예외처리를 통해 오류를 잡아내거나, 명시적인 예외를 발생시켜 디버깅에 활용할 수 있다.
#
# :::

# %% [markdown]
# > File I/O와 Exception Handlig
#
# - 일반적으로 프로그램에서 에러가 발생하는 것은 코드의 오류에서도 발생하나, Input()으로 입력받는 데이터의 문제, 입/출력시에 다루어야할 파일의 부재 혹은 파일속에 데이터가 형식에 맞지 않을 때 에러가 많이 발생한다. 즉 프로그램 입출력을 비롯한 파일 입출력시 에러가 주로 발생하므로 이때 예외처리(Exception Handling)가 필요하다.
#
# - 데이터를 휘발성메모리인 램에 저장할 경우 프로그램을 종료하거나 전원을 끄면 사라지기 때문에 비휘발성메모리에 저장해야 한다. 이때 파일에 저장할 데이터의 양이 크지 않거나 혼자 볼 데이터라면 파일로 저장하면 되지만, 다수에 동시 사용자가 다뤄야 할 데이터라면 데이터베이스에 저장해야 한다. 따라서 파일입출력과 함께 데이터베이스의 query언어인 SQL을 마지막에 넣었으니 살펴보기 바란다.

# %% [markdown]
# ## 파일시스템 관리 도구

# %% [markdown]
# - 윈도우, 리눅스, 맥 등 모든 컴퓨터에는 파일 시스템이 존재한다.
# - 파일 시스템은 파일들을 적절한 방식으로 관리 즉, 생성, 복사, 이동, 삭제 할 수 있도록 도와주는 시스템이다.
# - 파일을 관리할 수 있도록 도와주는 도구에는 대표적으로 `GUI를 이용`한 파일관리 도구와 `쉘커맨드(shell command)를 이용`한 파일관리 도구가 있다.

# %% [markdown]
# - GUI(Graphic User Interface)를 이용한 파일 관리도구로는 대표적으로 `파일 탐색기`가 있다.
# - **파일 탐색기**를 통해 파일 목록을 볼 수도 있고 파일을 생성, 이동, 삭제, 복사 하는 등 다양한 파일 관리 작업을 할 수 있다.
#
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/file1.png" style="width:400px;"></div>

# %% [markdown]
# - 쉘커맨드를 이용한 파일 관리도구로는 대표적으로 `명령프롬프트`가 있다.
# - 쉘커맨드는 GUI가 나오기 전 파일 관리도구로 사용되었으며, 현재의 파일 탐색기에서 하는 모든 작업을 쉘커맨드로도 할 수 있어서 쉘커맨드에 익숙한 사용자들은 여전히 많이 사용한다.
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/file2.png" width="300"></div>

# %% [markdown]
# - 때로는 프로그램을 통해서도 파일 관리가 요구되기도 있다.
# - 프로그래밍 언어를 통해서도 파일 관리를 할 수 있으며, 파이썬에서도 파일관리를 위한 쉘커맨드를 지원한다.
#
#
# - 파이썬에서 파일관리를 하려면 먼저 모듈 os를 import해야 한다.
# - 모듈 os에는 system()이라는 함수가 있다.
# - os.system() 함수는 파이썬이 컴퓨터의 운영체제(os: operating system,[윈도우, 맥, 리눅스 등])에게 명령어를 전달하도록 한다.
# - os.system() 괄호안에 운영체제 명령어를 넣어주면 된다.
# ```
# import os
# os.system(운영체제명령어)
# ```

# %% [markdown]
# - 예를 들어, os.system('dir') 하면 파일목록을 보여라는 dir 명령을 파이썬에서 수행한다.
# - 그러나, 파이썬의 쉘커맨드에서는 아래의 코드가 실행되어 현재 위치의 파일 목록을 나타내지만 코랩에서는 0(return value)으로 나온다.
# ```
# import os
# os.system('dir')
# ```
# - 이를 위해 실행한 시스템 명령어의 결괏값을 돌려받는 popen()함수를 사용할 수 있다.
# ```
# f = os.popen("dir")
# print(f.read())
# ```

# %%
import os
os.system('dir')

# %%
f = os.popen("dir")
print(f.read())

# %% [markdown]
# - 더 간단한 방법은 파이썬 쉘명령어 앞에 `!`를 붙이면 운영체제 명령어가 실행된다.
# - ls는 현재 위치의 파일목록을 보여주라는 리눅스 명령어이다.
# - dir은 현재 위치의 파일목록을 보여주라는 윈도우 명령어이다.

# %%
# !ls
# !dir

# %% [markdown]
# - 운영체제명령어를 실행하는 독립적인 함수들도 있다.
#   - listdir() : 폴더의 목록을 보여준다.
#   - chdir(폴더명): 폴더명이 적힌 폴더로 이동한다.
#   - getcwd(): 현재 폴더 경로를 반환
#
# - 아래 코드를 실행시키면 현재 위치의 파일 목록이 나온다.
# ```python
# import os
# os.listdir()
# ```
#
# - 아래 코드는 현재 위치를 'sample_data' 폴더로 이동시킨다. 이동했다는 결과가 보이지는 않으므로 os.getcwd()을 통해 현재 위치를 반환해보면 폴더로 이동했음을 확인할 수 있다.
# ```python
# os.chdir('sample_data')
# os.getcwd()
# ```

# %%
import os
os.listdir()

# %%
os.chdir('sample_data')
os.getcwd()

# %%
os.listdir()

# %%
os.chdir('/content')

# %%
os.getcwd()

# %% [markdown]
# ## 메인 메모리 vs. 파일 시스템 특징

# %% [markdown]
# - 파일 관리에 하나인 `자료를 저장한다`는 측면에서 메인 메모리와 파일시스템의 역할을 비교해서 따져보자.

# %% [markdown]
# ### 메인 메모리(주기억 장치)의 특징
# - 메인 메모리는 전원을 끄면 자료가 사라져버리는 Volatile(휘발성) 메모리이다.
# - 메인 메모리에는 주소가 있어서 그 주소에 있는 값을 읽어 올 수도 쓸 수도 있는 랜덤 엑세스(Random access)가 가능하다.
# - 랜덤엑세스가 가능해서 속도가 빠르지만 저장할 수 있는 양은 크지 않다(8 to 16Gb).
# - 가격이 비싸다.

# %% [markdown]
# ### 파일 시스템의 특징
# - 전원을 꺼도 자료가 사라지지 않는 비휘발성(Non-volatile)메모리이다.
# - 하드디스크(HDD), USB메모리 등이 파일시스템으로 사용되는 보조기억장치에 속한다.
# - HDD는 자료를 읽어올 때 순차적 엑세스(Sequential access)로 처음부터 순서대로 읽어나간다. 물론 부분적으로 랜덤 엑세스가 가능하다.
# - 속도는 느리지만 저장할 수 있는 양은 메인 메모리보다 몇 백배 크다. (512Gb to 3Tb)
# - 떨어뜨리면 고장이 날 수도 있다.
#   - 예전의 하드디스크 참고자료
#     - Tape: https://www.youtube.com/watch?v=7Lh4CMz_Z6M&ab_channel=CuriousMarc
#     - Disc: https://www.youtube.com/watch?v=3WFnVFrPf5Q&ab_channel=80sCompaqPC
# - 요즘의 대부분의 노트북들은 Flash 메모리(SSD, USB memory)를 사용한다.
# - Flash 메모리는 주기억장치인 램과 HDD의 중간정도 위치라고 볼 수 있는데 자료를 읽을 때 랜덤 엑세스로 읽는다.

# %% [markdown]
# ## 메인 메모리 엑세스 vs. 파일 시스템 엑세스

# %% [markdown]
# ### 메인 메모리 엑세스
#
# - 프로그래밍 언어에서는 변수를 선언하면 메인메모리에 저장하며 엑세스가 가능하다.

# %%
a=10
print(a)

# %% [markdown]
# ### 파일 시스템 접근
#
# - 여기에서는 파일시스템에서 파일을 다루는 가장 단순한 기법만 언급할 것이다.
# - 왜냐면 여러분들이 더 낮은 레벨에서의 파일시스템을 건들거나 다룰 일이 거의 없을 것이기 때문이다.
# - 여러분들이 파일시스템을 다루는 작업이 필요하지 않을 수도 있고, 혹은 필요한 사람들은 파일시스템에서 다루는게 아니라 보통은 데이터베이스에서 다룰 일이 많을 것이기 때문이다.

# %% [markdown]
# - 파일시스템을 엑세스 할때에는 메인메모리를 엑세스처럼 간단하지 않다.
# - 파일시스템을 엑세스 할 때에는 파일을 오픈할 때 읽을 것인지 쓸 것인지 등 엑세스 모드를 미리 알려줘야 한다.
# - 엑세스 모드는 다음과 같다.
#   - r: 읽는 용도. 파일이 없을때는 에러가 난다.
#   - w: 쓰는 용도. 파일이 이미 있다면 다 지우고 처음부터 쓰고, 없다면 새로 만든다.
#   - a: 쓰는 용도. 파일이 이미 있다면 내용의 가장 마지막에 추가한다.
#   - r+: 읽기/쓰기 용도. r모드는 순서대로만 읽으나, r+ 모드에서는 읽을위치, 쓸위치로 직접 이동이 가능하다.
#   - w+ : 읽기/쓰기 용도. 파일이 이미 있다면 다 지우고 처음부터 쓴다.
#
# - 파일을 오픈해보자.

# %% [markdown]
# #### 파일 열기: open()
#
# - 파일을 열 때 사용하며, 인자로 파일명과 엑세스 모드를 넣어준다.
# ```
# open(파일명, 엑세스 모드)
# ```

# %% [markdown]
# - 아래 코드에서는 newfile.txt파일을 쓰는 용도로 오픈한다.
# - 오픈한 파일 객체를 변수 f에 저장한다. 이제 변수 f를 통해서 파일에 접근할 수 있다.
# - 파일이 기존에 없었기 때문에 새로 만들어졌을 것이다.
# - 코랩 메뉴의 왼쪽의 파일 아이콘을 누르면 확인이 된다.
# - 파일은 아직은 내용이 없는 빈 파일이다.
# ```python
# f = open("newfile.txt", 'w')
# ```

# %%
f = open("newfile.txt", 'w')

# %% [markdown]
# #### 파일 쓰기: write()
#
# - 파일에 쓸 때 사용하며, 인자로 데이터를 넣어준다.
# ```
# 파일객체.write(데이터)
# ```

# %% [markdown]
# - 반복문을 통해 파일에 문자열을 써보자.
# - 위에서 만들었던 파일객체 f는 쓰기모드로 열었기 때문에 파일에 데이터를 저장할 수 있다.
# - 아래 코드는 f.write(data)로 newfile.txt 파일에 데이터를 저장한다.

# %%
for i in range(1, 11):
  data = f"{i}번째 줄입니다.\n"
  f.write(data)

# %% [markdown]
# #### 파일 닫기: close()
#
# - 파일을 닫을 때 사용한다. 파일을 열었다면 반드시 닫어줘야 한다. 파일을 닫지 않으면 파일 내부에 있는 데이터가 손상 될 수도 있고, 다른 프로세스에서 해당 파일에 엑세스를 못 할 수도 있다.
# ```
# 파일객체.close()
# ```
# - 아래 코드는 파일 객체 f를 닫아준다.

# %%
f.close()

# %% [markdown]
# - 파일 오픈을 with 문으로 대체하면 with를 벗어날 때 자동으로 파일을 닫아주므로 close() 함수를 사용할 필요가 없다.
# ```python
# with open("newfile.txt", "r") as f:
#     for i in range(1, 11):
#           data = f"{i}번째 줄입니다.\n"
#           f.write(data)
# ```

# %%
with open("newfile.txt", "w") as f:
  for i in range(1, 11):
    data = f"{i}번째 줄입니다.\n"
    f.write(data)

# %% [markdown]
# #### 파일 읽기

# %% [markdown]
# ##### read()
#
# - 파일의 전체의 내용을 하나의 문자열로 읽어온다.
# ```python
# 파일객체.read()
# ```

# %% [markdown]
# - 이제 "newfile.txt" 파일을 읽기용으로 열어서 read()함수로 파일에서 데이터를 읽어보자.
# - 앞에서 저장했던 결과가 잘 출력 될 것이다.
# - 파일을 읽어온 후 한 번 더 read()를 실행시키면 더 이상 읽을 내용이 없어서 빈 문자열을 반환한다.
#
# ```python
# with open("newfile.txt", "r") as f:
#     data = f.read()
#     print(data)
#     f.read()
#
# ```
#
# ```
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.
# 6번째 줄입니다.
# 7번째 줄입니다.
# 8번째 줄입니다.
# 9번째 줄입니다.
# 10번째 줄입니다.
# ```

# %%
with open("newfile.txt", "r") as f:
    data = f.read()
    print(data)
    f.read()

# %% [markdown]
# ##### readline()
# - 한번에 한 줄씩 읽어온다.
# - 읽어온 내용의 맨 끝에는 줄바꿈 기호('\n')가 들어가 있고, 반복문에서 print()에 의해 줄이 바뀌므로 결과는 내용 출력 후 빈줄이 출력될 것이다.
#
# ```python
# with open("newfile.txt", "r") as f:
#     while True:
#         line = f.readline()
#         if not line:
#           break
#         print(line)
#
# ```

# %%
with open("newfile.txt", "r") as f:
    while True:
        line = f.readline()
        if not line:
          break
        print(line)

# %% [markdown]
# - rstrip()은 문자열 오른쪽 끝에 들어가 있는 공백을 모두 제거해준다. 줄바꿈도 공백이므로 제거된다. 참고로 lstrip()은 왼쪽 공백을 제거해준다.
# ```python
# with open("newfile.txt", "r") as f:
#     while True:
#         line = f.readline()
#         if not line:
#           break
#         print(line.rstrip())
# ```

# %%
with open("newfile.txt", "r") as f:
  while True:
      line = f.readline()
      if not line:
        break
      print(line.rstrip())

# %% [markdown]
# ##### readlines()
# - 파일 전체 내용을 한 줄씩 읽어와서 리스트를 만들어준다.
# ```python
# with open("newfile.txt", "r") as f:
#     lines = f.readlines()
#     for line in lines:
#         print(line.rstrip())
# ```
# - 리스트이므로 언팩킹(unpacking) 기호인 *를 붙여서 한번에 내용만 출력이 가능하다.
# - 이때 리스트의 아이템마다 분리해주는 기능인 한 칸 띄어쓰기 기능이 적용되어서 한 칸씩 들어가 출력된다.
# ```python
# with open("newfile.txt", "r") as f:
#     lines = f.readlines()
#     print(*lines)
# ```

# %%
with open("newfile.txt", "r") as f:
  lines = f.readlines()
  print(lines)

# %%
a= [1,2,3]
print(*a)

# %%
with open("newfile.txt", "r") as f:
  lines = f.readlines()
  print(*lines)

# %% [markdown]
# #### 쉘커맨드로 읽기
# - 파일안의 내용이 길지 않다면 간단하게 리눅스 쉘커맨드로 내용을 확인할 수도 있다.
# ```
# !cat newfile.txt
# ```

# %%
# !cat newfile.txt

# %% [markdown]
# ## 예외처리(Exception Handling)
#
# - 예외처리는 프로그램 실행 중 발생할 수 있는 오류를 예측하고, 이를 효과적으로 처리하여 프로그램의 비정상 종료를 방지하는 방법이다.
# ---
# - Syntax error
#   - 예: while True print('Hello world')
# - Divided by zero
#   - 예: 10 * (1/0)
# - Type error
#   - 예: '2' + 2
# - Value error
#   - 예: int('이천')
# - Name error
#   - 예: 4 + spam*3
# - Index error
#   - 예:
# ```
# a=[1,2,3]
# print(a[0], a[1], a[2], a[3])
# ```

# %% [markdown]
# ### 예외를 처리하는 방법
# - try~except
#
# ```
# try:
#     # 오류가 발생할 가능성이 있는 코드
#     # 만약 이 블록 안에서 예외(오류)가 발생하지 않으면, except 블록은 건너뛰고 다음 코드가 실행된다.
# except:
#     # 오류가 발생했을 때 실행될 코드
#     # 여기서 오류를 처리하거나, 오류에 따른 대체 동작을 정의할 수 있다.
# ```

# %%
count = 1
while True:
    try:
        x = int(input("Please enter a number: "))
        count += 1
        if count == 5:
          break
    except ValueError:
        print("Oops!  That was no valid number.  Try again...")
        count -= 1

# %%
x = int(input("Please enter a number: "))

# %%
count = 1
while True:
  try:
      x = int(input("Please enter a number: "))
      count += 1
      if count == 5:
        break
      print(4/x)
  except ValueError:
      print("Oops!  That was no valid number.  Try again...")
      count -= 1
  except ZeroDivisionError:
      print("0으로 나눌 수 없습니다. Try again...")
      count -= 1

# %%
try:
    a = [1,2]
    print(a[3])
except ZeroDivisionError as e:
    print(e)
except IndexError as e:
    print(e)

# %%
try:
    a = [1,2]
    4/0
    print(a[3])
except (ZeroDivisionError, IndexError) as e:
    print(e)

# %%
try:
   number1, number2 = eval(input('두 숫자를 컴마로 분리하여 입력하세요. '))
   result = number1/number2
   print('결과는', result, '입니다.'  )
except ZeroDivisionError:
     print('0으로 나누었습니다.')
except SyntaxError:
     print('입력에 컴마가 없습니다.')
except:
     print('입력에 문제가 있습니다.')
else: #모든 except문 뒤에 와야 함
     print('예외가 발생하지 않았습니다. ')
finally: #에러가 발생하든 안하든 처리할 코드
     print('try문을 빠져나갑니다.')

# %%
# 라인 10~12에서 발생할 수 있는 에러
# 1. 파일이 없을 수 있다.
# 2. read permission이 없을 수 있다.
# 3. 텍스트파일이 아니라 바이너리파일일 수 있다.
# 4. 파일의 내용이 없을 수 있다.
# 5. 숫자가 아니라 문자일 수 있다.
import sys

try:
    f = open('newfile.txt')
    s = f.readline()
    i = int(s.strip())
except OSError as err:
    print(f"OS error: {err}")
except ValueError:
   print("Could not convert data to an integer.")
except:
    print("Unexpected error:", sys.exc_info())
    print("Unexpected error:", sys.exc_info()[0])

# %% [markdown]
# ### 예외를 발생시키는 방법
# - assert: 코드 실행 중 특정 조건이 참(true)인지 확인하고, 그렇지 않을 경우 예외를 발생시켜 디버깅에 도움을 주기 위해 사용한다. AssertionError를 발생시킨다.
#   - 디버깅을 위한 목적이라면 assert가 사용된다.
# - raise: 특정 조건이 발생했을 때, 명시적으로 예외를 발생시키기 위해 사용한다.
#   - 다양한 예외 타입을 발생시킬 수 있다. 따라서 에러 내용을 구체적으로 명시하고자 할 땐 raise가 사용된다.
#   - 실제 서비스에서 상태를 알리는 것이 목적이라면 raise가 사용된다.

# %% [markdown]
# - assert 문을 사용하면 AssertionError 를 출력하면서 코드가 종료, raise 문을 사용하면 AssertionError 뿐만 아니라 AttributeError, ValueError, importError 등 기타 다른 에러도 출력하여 코드를 종료시킬 수 있다.
# - 따라서 간단한 디버그를 위해서는 assert 문을,에러 내용을 구체적으로 명시하고자 할 땐 raise 구문을 사용하는 것이 좋다.

# %%
age = int(input("나이 입력 : "))

assert age >= 0, '인간의 나이는 마이너스일 수 없습니다.'
print(f"당신의 나이는 : {age}살 입니다")

# %%
try:
    age = int(input("나이 입력 : "))
    assert age >= 0

except AssertionError:
    print('인간의 나이는 마이너스일 수 없습니다.')
else:
    print(f"당신의 나이는 : {age}살 입니다")

# %%
try:
    x = int(input('3의 배수를 입력하세요: '))
    if x % 3 != 0:                                # x가 3의 배수가 아니면
        raise Exception('3의 배수가 아닙니다.')    # 예외를 발생시킴
    print(x)                                      # 예외가 발생하면 raise 아래 문장은 실행되지 않음
except Exception as e:                            # 예외가 발생했을 때 실행됨
    print('예외가 발생했습니다.', e)
# Out:
# 3의 배수를 입력하세요: 5
# 예외가 발생했습니다. 3의 배수가 아닙니다.

# %%
bottom=5
if bottom != 0:
    raise ValueError('bottom이 5가 아닙니다.')
    #raise Exception('bottom이 5가 아닙니다.')

# %% [markdown]
# ## 데이터베이스(SQL) 활용하기
# - 사용자와 DBMS가 소통하기위해 사용하는 Structured Query Language
# - colab에서 DB와 연동하기 위해서는 DB파일이 colab저장소에 있어야 함

# %% [markdown]
# 1. SQLite 공식 웹사이트(https://www.sqlite.org/download.html)에서 "Precompiled Binaries for Windows"에 있는 sqlite-tools-win32-x86-{version number}.zip을 다운로드합니다.
#
# 2. 압축을 풀고 SQLite3.exe 파일을 원하는 위치에 저장
# 3. 명령 프롬프트를 열고 SQLite3.exe 파일이 있는 폴더로 이동
# 4. SQLite3.exe를 실행하여 SQLite 데이터베이스를 만들거나 기존 데이터베이스에 연결할 수 있
# 5. 설치 완료

# %% [markdown]
# ### DB 연결

# %%
import sqlite3
con = sqlite3.connect('testDB')

# %%
cur = con.cursor()

# %% [markdown]
# ### 테이블 생성

# %%
cur.execute("create table cuserTable(id TEXT, name TEXT, email TEXT, birthYear INTEGER)")

# %% [markdown]
# ### 데이터 저장

# %%
cur.execute("insert into cuserTable values('john', 'John Bann', 'john@naver.com',1990)")
cur.execute("insert into cuserTable values('kim', 'Kim Chi', 'kim@naver.com',1992)")
cur.execute("insert into cuserTable values('Lee', 'Lee Ppal', 'lee@gmail.com',1988)")
cur.execute("insert into cuserTable values('Park', 'Park Su', 'park@gmail.com',1980)")

# %% [markdown]
# ### 명령 실행

# %%
con.commit()

# %% [markdown]
# ### 데이터 조회

# %%
cur.execute("select * from cuserTable")

# %%
while True:
   row = cur.fetchone()
   if row == None:
      break
   data1 = row[0]
   data2 = row[1]
   data3 = row[2]
   data4 = row[3]
   print(data1,'|', data2,'|', data3,'|', data4)
# Out:
# john | John Bann | john@naver.com | 1990
# kim | Kim Chi | kim@naver.com | 1992
# Lee | Lee Ppal | lee@gmail.com | 1988
# Park | Park Su | park@gmail.com | 1980

# %% [markdown]
# ### DB 연결종료

# %%
con.close()

# %% [markdown]
# ## 마무리
# - 파일 시스템 관리는 파일을 열고, 읽고, 쓰고, 닫고, 복사하고, 지우고 등의 파일을 관리하는 것을 의미한다.
# - 파이썬에서 파일시스템의 파일을 엑세스하는 open(), write(), close(), read() 함수에 대해서 알아보았다.
# - 파일시스템을 엑세스 할 때에는 파일을 오픈할 때 읽을 것인지 쓸 것인지 등 엑세스 모드를 미리 알려줘야 한다.
# - 엑세스 모드는 다음과 같다.
#   - r: 읽는 용도. 파일이 없을때는 에러가 난다.
#   - w: 쓰는 용도. 파일이 이미 있다면 다 지우고 처음부터 쓰고, 없다면 새로 만든다.
#   - a: 쓰는 용도. 파일이 이미 있다면 내용의 가장 마지막에 추가한다.
#   - r+: 읽기/쓰기 용도. r모드는 순서대로만 읽으나, r+ 모드에서는 읽을위치, 쓸위치로 직접 이동이 가능하다.
#   - w+ : 읽기/쓰기 용도. 파일이 이미 있다면 다 지우고 처음부터 쓴다.
#
# - 예외처리는 프로그램 실행 중 발생할 수 있는 오류를 예측하고, 이를 효과적으로 처리하여 프로그램의 비정상 종료를 방지하는 방법이다.
# - try-except 구문을 사용해 오류를 잡아내고, 필요시 finally로 항상 실행할 코드를 지정할 수 있다.
# - raise로 명시적인 예외를 발생시키거나, assert로 조건이 맞지 않을 때 예외를 유발하여 디버깅에 활용할 수 있다.

# %% [markdown]
# ---
# <font color='Grey' size="4">
# L0444.000500 컴퓨팅 핵심: 컴퓨터로 생각하기(Core Computing: Thinking with Computers)</font>
#
# ---

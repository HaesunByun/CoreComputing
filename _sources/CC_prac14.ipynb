# %% [markdown]
# # 실습 WEEK14: 알고리즘 설계기법

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 도움이 됩니다.
# - **<font color='blue'>도전 실습 문제는 etl>우리강좌>코딩수업>에 접속한 후, 해당 주차 문제의 소스코드를 제출하여 테스트를 통과해야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 코딩수업(엘리스코딩)의 해당 주차 응시 기간을 확인해주세요.</font>**
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도 풀이를 하지 않습니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# ## [사전 실습 문제]

# %% [markdown]
# ### Problem: 배열 합치기

# %% [markdown]
# 😄 정렬되어있는 두 배열 A와 B가 주어진다. 두 배열을 합친 다음, 정렬해서 출력하는 프로그램을 작성하시오.
#
# 첫째 줄에 배열 A의 내용이, 둘째 줄에는 배열 B의 내용이 주어진다.
# 머지소트의 정렬 방법을 통해 정렬해주세요. 파이썬의 sort기능을 사용하면 안됩니다.
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 3 5
# 2 9
# ```
# Output Sample
#
# ```
# 배열(A):
# 배열(B):
# Result: 2 3 5 9
# ```
#
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 2 3 5 9
# 1 4 7
# ```
# Output Sample
#
# ```
# 배열(A):
# 배열(B):
# Result: 1 2 3 4 5 7 9
# ```

# %% [markdown]
# ## [도전 실습 문제]

# %% [markdown]
# ### Problem: (함께) SNU 게임
#
# 😄 가을이와 이서가 다음 규칙에 따라 'SNU 게임'에 참여한다고 하자.
#
# (1) 먼저 가을이가 세 글자 문자열 SNU를 생성한다.
#
# (2) 다음으로 이서는 SNU와 SNU 사이에 ♥ 기호를 한 개 넣어 새 문자열 SNU♥SNU를 생성한다.
#
# (3) 이윽고 가을이는 SNU♥SNU와 SNU♥SNU 사이에 ♥ 기호를 두 개 넣어 새 문자열 SNU♥SNU♥♥SNU♥SNU를 생성한다.
#
# (4) 이서는 가을이가 만든 문자열 SNU♥SNU♥♥SNU♥SNU에 ♥ 기호를 세 개 넣어 새 문자열 SNU♥SNU♥♥SNU♥SNU♥♥♥SNU♥SNU♥♥SNU♥SNU를 만든다.
#
# (5) 이와 같이 이전단계에서 만들어진 문자열 사이에 ♥ 기호가 하나씩 추가되어 새로운 문자열을 만드는 과정이 반복된다.
#
# 위와 같이 SNU 게임을 시행하면 SNU를 포함하는 무한히 긴 문자열이 생성되는데 이를 X라 하자. 사용자로부터 자연수 N을 입력받아, X의 N번째 문자를 출력하는 Python 프로그램을 작성하시오. **단, 프로그램 실행 과정에서 입력값을 제외하고 새로운 문자열이나 list를 생성하지 않아야 한다.**
# 자연수 N: 1<= N < 100000000000000000000000000000
#
# ---
# Input Sample
# ```
# 10
# ```
# Output Sample
# ```
# N:
# X의 10번째 문자: S
# ```
#
# ---
# Input Sample
# ```
# 30
# ```
# Output Sample
# ```
# N:
# X의 30번째 문자: N
# ```
# ---
# Input Sample
# ```
# 4838382727383947366262283
# ```
# Output Sample
# ```
# N:
# X의 4838382727383947366262283번째 문자: ♥
# ```

# %% [markdown]
# 문제 해결 아이디어
# - 분할정복과 동적계획법을 활용해보자.
# - 문자열 X는 단계적으로 아래와 같이 만들어진다.
#   - $X_0$ = SNU
#   - $X_1$ = SNU♥SNU
#   - $X_2$ = SNU♥SNU♥♥SNU♥SNU
#   - $X_3$ = SNU♥SNU♥♥SNU♥SNU♥♥♥SNU♥SNU♥♥SNU♥SNU
#   - ...
# - 재귀적 규칙을 적용하면 아래와 같다.
#   - $X_k$ = $X_{k-1}$ + $K$개의 ♥ + $X_{k-1}$
#   - 각 단계에서 문자열은 이전 단계의 문자열 두개와  $K$개의 ♥ 기호로 구성된다.
#
# - 문자열의 길이 $L_k$는
#   - $L_0$ = 3(SNU의 길이)
#   - $L_k$ = 2* $L_{k-1}$ + $K$
#   - 이를 동적계획법으로 계산하여 중복 계산을 줄일 수 있다.

# %% [markdown]
# ## [완전 실습 문제]

# %% [markdown]
# ### Problem: (함께)줄 합치기<분할정복>

# %% [markdown]
# 😄 서울유치원에는 햇님반과 달님반이 있습니다. 햇님반과 달님반의 학생들은 선생님 앞에서 키 순서로 정렬합니다. 어느 날 햇님반과 달님반이 합쳐져 해달반이 되었습니다. 그래서 예전 반에 따라 키 순으로 두 줄로 선 해달반 학생들을 한 줄로 합쳐야 합니다. (해달반 학생들의 키는 모두 다릅니다.) 그 때 해달반의 Merge 선생님이 두 줄을 합치는 방식을 설명했습니다.
#
# ```
# 우선 해달반을 위한 새로운 빈 줄을 만든다.
# 햇님반의 가장 작은 아이와 달님반의 가장 작은 아이의 키를 비교한 뒤, 더 작은 아이가 해달반의 줄로 간다.
# 그 후에 다시 남은 아이들 중 햇님반의 가장 작은 아이와 달님반의 가장 작은 아이를 비교한 뒤, 더 작은 아이가 해달반 줄의 뒤쪽에 선다.
# 이런 식으로 원래의 한 줄이 모두 없어질 때까지 한 뒤, 남아있는 다른 줄의 아이는 모두 그대로 한 명씩 해달반 줄의 뒤쪽으로 간다.
# ```
#
# 햇님반의 궁금이 선생님은 해달반 줄에 친구가 한 명씩 새로 올 때마다 해달반 줄의 모습을 알고 싶습니다. 궁금이선생님을 위해 줄을 합치는 과정을 출력해주세요.
# 입력으로는 햇님반과 달님반 학생들의 이름과 키가 두 개의 정렬된 딕셔너리 안에 담겨 들어옵니다. 이에 따라, 새로운 해달반 줄에 친구가 한 명씩 들어오는 과정을 print_list 함수를 이용해 한 줄씩 출력해 주세요.
# 파이썬의 sort 기능을 사용하면 안됩니다.

# %% [markdown]
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# {"가영":120, "나영": 130, "미선": 165, "승재": 185, "현태": 190}
# {"다영":105, "바영": 125, "사영": 150, "라영": 156, "마영": 157, "예원": 178}
# ```
# Output Sample
# ```
# 다영
# 다영, 가영
# 다영, 가영, 바영
# 다영, 가영, 바영, 나영
# 다영, 가영, 바영, 나영, 사영
# 다영, 가영, 바영, 나영, 사영, 라영
# 다영, 가영, 바영, 나영, 사영, 라영, 마영
# 다영, 가영, 바영, 나영, 사영, 라영, 마영, 미선
# 다영, 가영, 바영, 나영, 사영, 라영, 마영, 미선, 예원
# 다영, 가영, 바영, 나영, 사영, 라영, 마영, 미선, 예원, 승재
# 다영, 가영, 바영, 나영, 사영, 라영, 마영, 미선, 예원, 승재, 현태
# ```

# %% [markdown]
# ### Problem: 거듭제곱
#
# 😄 자연수 A를 B번 곱한 수를 알고 싶다. 단 구하려는 수가 매우 커질 수 있으므로 이를 C로 나눈 나머지를 구하는 프로그램을 작성하시오. 첫째 줄에 A, B, C가 빈 칸을 사이에 두고 순서대로 주어진다.
#
# ---
# Input Sample
# ```
# 10 11 12
# ```
# Output Sample
# ```
# A, B, C:
# 나머지: 4
# ```
# ---
# Input Sample
# ```
# 2 10 3
# ```
# Output Sample
# ```
# A, B, C:
# 나머지: 1
# ```

# %% [markdown]
# ### Problem: 가까운 이웃찾기
#
# 😄 한 이상한 마을이 있습니다. 그 마을에서는 집이 가장 가까운 이웃과만 얘기를 할 수 있습니다. 각 가구의 집 위치는 이차원 좌표(x, y)로 0~50사이의 값이 각각 주어집니다.
# 집 주인의 이름과 위치를 입력받아 가장 가까운 이웃을 찾아주세요. i 집 (x,y)와 j의 집 (x,y) 거리는 다음 공식을 이용하여 구할 수 있습니다.

# %% [markdown]
# $d(i,j) = \sqrt{(x_j-x_i)^2 + (y_j-y_i)^2}$
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 첫 번째 줄에 집주인의 이름이 리스트로 입력됩니다.
# 두 번째 줄에 모든 집의 위치가 리스트로 입력됩니다.
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# ["jungsick","minchol", "meesun", "seungjae", "hyuntae", "woosung", "yewon","yongjae", "junho","juno"]
# [[13, 34],[29, 35],[41,  6],[27, 32], [29,  0],[21, 16],[ 1, 37],[ 7,  3],[35,  7],[43, 37]]
# ```
# Output Sample
# ```
# jungsick의 이웃: yewon
# minchol의 이웃: seungjae
# meesun의 이웃: junho
# seungjae의 이웃: minchol
# hyuntae의 이웃: junho
# woosung의 이웃: junho
# yewon의 이웃: jungsick
# yongjae의 이웃: woosung
# junho의 이웃: meesun
# juno의 이웃: minchol
# ```

# %%
import numpy as np
x = np.random.randint(0, 50, (10, 2))

# %%
# ["jungsick","minchol", "meesun", "seungjae", "hyuntae", "woosung", "yewon","yongjae", "junho","juno"]
# [[13, 34],[29, 35],[41,  6],[27, 32], [29,  0],[21, 16],[ 1, 37],[ 7,  3],[35,  7],[43, 37]]
# [[16, 26],[30, 15],[19, 30],[34,  7],[27, 35],[36, 16],[ 3,  8],[43, 39],[18, 13],[35, 33]]

# %% [markdown]
# ### Problem: 가까운 이웃 그래프로 나타내기
#
# 😄  윗 문제에서 찾은 가까운 이웃을 그래프로 나타내보세요. 아래와 같은 matplotlib 함수들을 사용할 수 있습니다.
# ```
# plt.scatter(x,y)  : 좌표에 동그란 점을 찍는데 사용합니다.
# plt.text('snu') : 그래프에 이름을 출력하는데 사용합니다.
# plt.plot(x,y) : 동그란 점사이에 선을 잇는데 사용합니다.
# plt.show( ) : 그래프를 나타냅니다.
# ```

# %%
import ast
import matplotlib.pyplot as plt

nameList = ast.literal_eval(input())
locList = ast.literal_eval(input())

resident = []

for name, loc in zip(nameList, locList):
    resident.append((name, loc))
    plt.scatter(*loc)
    plt.text(*loc, name)

for curr in resident:
    # 이웃 탐색을 한줄의 코드로 줄이면
    neighbor = min( list(filter(lambda mm: mm[0] != curr[0], resident)), key = lambda nn: (nn[1][0] - curr[1][0])**2 + (nn[1][1] - curr[1][1])**2)
    plt.plot((curr[1][0], neighbor[1][0]), (curr[1][1], neighbor[1][1]))

plt.show()
# Out:
# ["jungsick","minchol", "meesun", "seungjae", "hyuntae", "woosung", "yewon","yongjae", "junho","juno"]
# [[13, 34],[29, 35],[41,  6],[27, 32], [29,  0],[21, 16],[ 1, 37],[ 7,  3],[35,  7],[43, 37]]

# %% [markdown]
# ### Problem: 별 찍기
#
# 😄 재귀적인 패턴으로 별을 찍어 보자. N이 3의 거듭제곱(3, 9, 27, ...)이라고 할 때, 크기 N의 패턴은 N×N 정사각형 모양이다.
#
# 크기 3의 패턴은 가운데에 공백이 있고, 가운데를 제외한 모든 칸에 별이 하나씩 있는 패턴이다.
# ```
# ***
# * *
# ***
# ```
#
#
# N이 3보다 클 경우, 크기 N의 패턴은 공백으로 채워진 가운데의 (N/3)×(N/3) 정사각형을 크기 N/3의 패턴으로 둘러싼 형태이다. 예를 들어 크기 27의 패턴은 Output Sample과 같다.

# %% [markdown]
# 첫째 줄에 N이 주어진다. N은 3의 거듭제곱이다. 즉 어떤 정수 k에 대해 N=3k이며, 이때 1 ≤ k < 8이다.
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 27
# ```
# Output Sample
#
# ```
# ***************************
# * ** ** ** ** ** ** ** ** *
# ***************************
# ***   ******   ******   ***
# * *   * ** *   * ** *   * *
# ***   ******   ******   ***
# ***************************
# * ** ** ** ** ** ** ** ** *
# ***************************
# *********         *********
# * ** ** *         * ** ** *
# *********         *********
# ***   ***         ***   ***
# * *   * *         * *   * *
# ***   ***         ***   ***
# *********         *********
# * ** ** *         * ** ** *
# *********         *********
# ***************************
# * ** ** ** ** ** ** ** ** *
# ***************************
# ***   ******   ******   ***
# * *   * ** *   * ** *   * *
# ***   ******   ******   ***
# ***************************
# * ** ** ** ** ** ** ** ** *
# ***************************
# ```
